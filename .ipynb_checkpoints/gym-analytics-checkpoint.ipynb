# %%
import pandas as pd
import numpy as np
df = pd.read_csv("gym.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#                         Name        Date  Type Primary Muscle  Sets  Reps  \
# 0              Dumbell Curls   3/20/2023  Pull         Biceps     3    10
# 1    Overhead Dumbell Raises   3/20/2023  Push        Triceps     3    10
# 2     Dumbell Shoulder Press   3/20/2023  Push      Shoulders     3    10
# 3        Dumbell Bench Press   3/20/2023  Push          Chest     3    10
# 4               Dumbell Rows   3/20/2023  Pull           Lats     3    10
# ..                       ...         ...   ...            ...   ...   ...
# 650             Dumbell Rows  12/26/2023  Pull           Lats     4    10
# 651           Preacher Curls  12/26/2023  Pull         Biceps     4    10
# 652         Hammerhead Curls  12/26/2023  Pull         Biceps     4    10
# 653       Incline Cable Rows  12/26/2023  Pull           Lats     4    10
# 654  Incline Supinated Curls  12/26/2023  Pull         Biceps     4    10
#
#     Weight (lbs) Notes
# 0             20   NaN
# 1             20   NaN
# 2             25   NaN
# 3             30   NaN
# 4             30   NaN
# ..           ...   ...
# 650           50   NaN
# 651           40   NaN
# 652           30   NaN
# 653           45   NaN
# 654           25   NaN
#
# [655 rows x 8 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%m/%d/%Y')

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month
df['year'] = pd.DatetimeIndex(df['Date']).year
mY = []
for x in range(len(df['month'])):
    mY.append(str(df['month'][x]) + '/' + str(df['year'][x]))
df['mY'] = mY
# Out:
#                                Name       Date  Type Primary Muscle  Sets  \
# Date
# 2023-03-20            Dumbell Curls 2023-03-20  Pull         Biceps     3
# 2023-03-20  Overhead Dumbell Raises 2023-03-20  Push        Triceps     3
# 2023-03-20   Dumbell Shoulder Press 2023-03-20  Push      Shoulders     3
# 2023-03-20      Dumbell Bench Press 2023-03-20  Push          Chest     3
# 2023-03-20             Dumbell Rows 2023-03-20  Pull           Lats     3
# ...                             ...        ...   ...            ...   ...
# 2023-12-26             Dumbell Rows 2023-12-26  Pull           Lats     4
# 2023-12-26           Preacher Curls 2023-12-26  Pull         Biceps     4
# 2023-12-26         Hammerhead Curls 2023-12-26  Pull         Biceps     4
# 2023-12-26       Incline Cable Rows 2023-12-26  Pull           Lats     4
# 2023-12-26  Incline Supinated Curls 2023-12-26  Pull         Biceps     4
#
#             Reps Weight (lbs) Notes  month  year  \
# Date
# 2023-03-20    10           20   NaN      3  2023
# 2023-03-20    10           20   NaN      3  2023
# 2023-03-20    10           25   NaN      3  2023
# 2023-03-20    10           30   NaN      3  2023
# 2023-03-20    10           30   NaN      3  2023
# ...          ...          ...   ...    ...   ...
# 2023-12-26    10           50   NaN     12  2023
# 2023-12-26    10           40   NaN     12  2023
# 2023-12-26    10           30   NaN     12  2023
# 2023-12-26    10           45   NaN     12  2023
# 2023-12-26    10           25   NaN     12  2023
#
#                                                           m/y       mY
# Date
# 2023-03-20  Date\n2023-03-20     3\n2023-03-20     3\n2023...   3/2023
# 2023-03-20  Date\n2023-03-20     3\n2023-03-20     3\n2023...   3/2023
# 2023-03-20  Date\n2023-03-20     3\n2023-03-20     3\n2023...   3/2023
# 2023-03-20  Date\n2023-03-20     3\n2023-03-20     3\n2023...   3/2023
# 2023-03-20  Date\n2023-03-20     3\n2023-03-20     3\n2023...   3/2023
# ...                                                       ...      ...
# 2023-12-26  Date\n2023-03-20     3\n2023-03-20     3\n2023...  12/2023
# 2023-12-26  Date\n2023-03-20     3\n2023-03-20     3\n2023...  12/2023
# 2023-12-26  Date\n2023-03-20     3\n2023-03-20     3\n2023...  12/2023
# 2023-12-26  Date\n2023-03-20     3\n2023-03-20     3\n2023...  12/2023
# 2023-12-26  Date\n2023-03-20     3\n2023-03-20     3\n2023...  12/2023
#
# [655 rows x 12 columns]

# %%
bodyweight = 145
for x in range(len(df['Weight (lbs)'])):
    if df['Weight (lbs)'][x] == 'bodyweight':
        df['Weight (lbs)'][x] = bodyweight

# %%
exercise = df[df['Name'] == "Bench Press"]

# %%
exercise
# Out:
#             Name       Date  Type Primary Muscle  Sets  Reps Weight (lbs)  \
# 17   Bench Press   4/4/2023  Push          Chest     2     8          115
# 18   Bench Press   4/4/2023  Push          Chest     2     6          115
# 93   Bench Press   6/8/2023  Push          Chest     4     6          115
# 122  Bench Press  6/13/2023  Push          Chest     4     6          135
# 173  Bench Press  6/24/2023  Push          Chest     4     6          135
# 232  Bench Press   7/5/2023  Push          Chest     4     8          115
# 261  Bench Press  7/11/2023  Push          Chest     4     4          135
# 290  Bench Press  7/16/2023  Push          Chest     4     6          135
# 381  Bench Press  8/15/2023  Push          Chest     4     8          135
# 431  Bench Press  9/10/2023  Push          Chest     4     6          155
# 476  Bench Press  9/28/2023  Push          Chest     4     4          165
# 601  Bench Press  12/9/2023  Push          Chest     4     8          155
#
#     Notes
# 17    NaN
# 18    NaN
# 93    NaN
# 122   NaN
# 173   NaN
# 232   NaN
# 261   NaN
# 290   NaN
# 381   NaN
# 431   NaN
# 476   NaN
# 601   NaN

# %%
plt.figure(figsize = (12,6))
plot =sns.lineplot(data = exercise, x = 'Date', y = 'Weight (lbs)', hue = 'Reps')
plot.invert_yaxis()
plt.show()

# %%
typeCount = df['Type'].value_counts()
typeCount
# Out:
# Type
# Push    226
# Pull    182
# Legs    126
# Core    120
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x ="Type", palette = 'flare')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df.dtypes
# Out:
# Name                      object
# Date              datetime64[ns]
# Type                      object
# Primary Muscle            object
# Sets                       int64
# Reps                       int64
# Weight (lbs)              object
# Notes                     object
# dtype: object

# %%
sns.countplot(data = df, x ="Type", hue = "mY", palette = 'flare')
# Out:
# <Axes: xlabel='Type', ylabel='count'>
